# %%
import ipynb.fs.full.data_to_file
import ipynb.fs.full.visualise_budget
import ipynb.fs.full.statistics
import pandas as pd


txt_file = "Apr.txt"
ipynb.fs.full.data_to_file.display_categories(out=True)
ipynb.fs.full.data_to_file.write_data(txt_file)
ipynb.fs.full.visualise_budget.visualise(txt_file)
ipynb.fs.full.statistics.stats_generate(txt_file)
# Out:
# [(0, 'salary'),
#  (1, 'fixed - must pay'),
#  (2, 'saving'),
#  (3, 'food'),
#  (4, 'beverage'),
#  (5, 'flower'),
#  (6, 'transport'),
#  (7, 'shopping'),
#  (8, 'others')]
# Brief Summary
# category  category_explain
# 0         salary              2078.68
# 1         fixed - must pay    -520.00
# 2         saving              -700.00
# 3         food                -261.48
# 4         beverage             -40.36
# 5         flower               -27.92
# 6         transport            -92.85
# 7         shopping            -141.58
# 8         others              -183.59
# Name: amount, dtype: float64
#
#
# Last 7 Days Expenses
# category  category_explain
# 3         food               -96.83
# 4         beverage           -40.36
# 6         transport          -49.80
# 7         shopping           -12.35
# 8         others             -93.30
# Name: amount, dtype: float64
